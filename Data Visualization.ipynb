# %% [markdown]
# # Loading the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df= pd.read_csv("C:/Users/DIBYOJIT/Downloads/archive (2)/Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # Histogram

# %%
plt.hist(df['CreditScore'],color="green")
# Out:
# (array([  19.,  166.,  447.,  958., 1444., 1866., 1952., 1525.,  968.,
#          655.]),
#  array([350., 400., 450., 500., 550., 600., 650., 700., 750., 800., 850.]),
#  <BarContainer object of 10 artists>)

# %%
sn.countplot(x='Geography', data= df)
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='count'>

# %% [markdown]
# # Boxplot

# %%
sn.boxplot(df['Tenure'],color="red")
# Out:
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure'>

# %%
print(df['Tenure'].quantile(0.05))
print(df['Tenure'].quantile(0.95))
# Out:
# 1.0
# 9.0

# %%
import numpy as np
df['Tenure']= np.where(df['Tenure']>9,9,df['Tenure'])
df['Tenure']= np.where(df['Tenure']<1,1,df['Tenure'])

# %%
sn.boxplot(df['Tenure'])
# Out:
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tenure'>

# %% [markdown]
# # Histogram2

# %%
plt.hist(df['CreditScore'],bins=30, color="brown")
# Out:
# (array([ 10.,   6.,   3.,  27.,  61.,  78., 103., 146., 198., 277., 320.,
#         361., 420., 481., 543., 607., 627., 632., 669., 690., 593., 613.,
#         510., 402., 391., 330., 247., 195., 117., 343.]),
#  array([350.        , 366.66666667, 383.33333333, 400.        ,
#         416.66666667, 433.33333333, 450.        , 466.66666667,
#         483.33333333, 500.        , 516.66666667, 533.33333333,
#         550.        , 566.66666667, 583.33333333, 600.        ,
#         616.66666667, 633.33333333, 650.        , 666.66666667,
#         683.33333333, 700.        , 716.66666667, 733.33333333,
#         750.        , 766.66666667, 783.33333333, 800.        ,
#         816.66666667, 833.33333333, 850.        ]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(df['Age'], df['Tenure'],marker='.',color= "blue")

# %% [markdown]
# # Pie Chart

# %%
slices= (0,0.1,0.1,0,0)
Age= [25,57,42,12,7]
Years= [2027,2059,3001,3013,3020]
plt.pie(Age,labels= Years, explode= slices, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c74f2b8e50>,
# ...
#  [Text(0.9382197048963911, 0.5742332151174547, '2027'),
#   Text(-0.8438550435949739, 0.8531756357276765, '2059'),
#   Text(-0.22278541342208433, -1.1791381002945969, '3001'),
#   Text(0.9253789595110392, -0.5947047849935853, '3013'),
#   Text(1.0870183560235824, -0.16849656871221041, '3020')],
#  [Text(0.5117562026707587, 0.31321811733679344, '17.5%'),
#   Text(-0.49224877543040135, 0.49768578750781123, '39.9%'),
#   Text(-0.12995815782954917, -0.6878305585051815, '29.4%'),
#   Text(0.5047521597332941, -0.3243844281783192, '8.4%'),
#   Text(0.5929191032855903, -0.0919072192975693, '4.9%')])

# %% [markdown]
# # Area Chart

# %%
datadict= {'sales': [250,280,360,420,450,560],
           'profit': [80,90,50,120,75,140]}
months= {"Jan","Feb","Mar","Apr","May","June"}
df1= pd.DataFrame(datadict, index=months)
df1
df1.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Meshgrid

# %%
x= np.random.randint(0,50,7)
y= np.random.randint(-10,10,5)
xval, yval= np.meshgrid(x,y)
print("X values= ")
print(xval)
print("Y values= ")
print(yval)
# Out:
# X values=
# [[18 39 43  3 27  5 21]
#  [18 39 43  3 27  5 21]
#  [18 39 43  3 27  5 21]
#  [18 39 43  3 27  5 21]
#  [18 39 43  3 27  5 21]]
# Y values=
# [[-4 -4 -4 -4 -4 -4 -4]
#  [ 2  2  2  2  2  2  2]
#  [ 7  7  7  7  7  7  7]
#  [-5 -5 -5 -5 -5 -5 -5]
#  [ 2  2  2  2  2  2  2]]

# %% [markdown]
# # Quiver Plot

# %%
x= np.linspace(3,7,10)
y= np.linspace(-3,15,8)
xval, yval= np.meshgrid(x,y)
v= np.tan(xval)
u= np.tanh(yval)
plt.quiver(xval,yval,u,v)

# %% [markdown]
# # Contour Plot

# %%
x= [-6,-4,-2,0,2,4,6]
y= [-3,-2,-1,0,1,2,3]
xval, yval= np.meshgrid(x,y)
zval= np.cos(xval)*np.sin(yval)
plt.contour(xval,yval,zval)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df= pd.read_csv("C:/Users/DIBYOJIT/Downloads/archive (2)/Churn_Modelling.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # Countplot

# %%
sn.countplot(x='Age',hue='IsActiveMember',data= df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# # Barplot

# %%
sn.barplot(x='CreditScore',y='Age', hue='HasCrCard', data=df)
# Out:
# <AxesSubplot:xlabel='CreditScore', ylabel='Age'>

# %% [markdown]
# # Pointplot

# %%
sn.pointplot(x='Geography',y='Tenure', hue='HasCrCard', data=df)
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='Tenure'>

# %% [markdown]
# # Violinplot

# %%
sn.violinplot(x='Tenure', y='Balance', hue='Exited', data=df)
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Balance'>

# %% [markdown]
# # Rugplot

# %%
sn.rugplot(df['EstimatedSalary'])
# Out:
# <AxesSubplot:xlabel='EstimatedSalary'>

# %% [markdown]
# # Catplot

# %%
sn.catplot(x='Age', y='Geography', data= df)

# %% [markdown]
# # Distplot

# %%
sn.distplot(df['EstimatedSalary'], color= 'blue')
# Out:
# <AxesSubplot:xlabel='EstimatedSalary', ylabel='Density'>

# %% [markdown]
# # Joint Dist Plot

# %%
sn.distplot(df[df['Geography']== 'HasCrCard']['CreditScore'], color= 'Magenta',label= "HasCrCard")
sn.distplot(df[df['Geography']=='No CrCard']['CreditScore'], color= 'Red',label= "No CrCard")
# Out:
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Jointplot

# %%
sn.jointplot(data= df, x='EstimatedSalary', y='Balance')

# %% [markdown]
# # Relplot

# %%
sn.relplot(data= df, x='Balance',y='EstimatedSalary', hue='CreditScore', col='IsActiveMember', style='CreditScore')

# %% [markdown]
# # Pairplot

# %%
cont= ['Age','Balance','EstimatedSalary']
sn.pairplot(df[cont],height=3)

# %% [markdown]
# # Swarmplot

# %%
sn.swarmplot(x='CreditScore',y='Balance',data=df)
# Out:
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %%
df= pd.read_csv("C:/Users/DIBYOJIT/OneDrive/Documents/EDA ass.csv")
df
# Out:
#     Employee no  Gender  Age  No of years of experience Education   Salary
# 0           123    Male   23                          2         UG   13000
# 1           124    Male   32                          8         PG   26000
# 2           125    Male   35                          8         UG   26000
# 3           126  Female   45                         10         PG   40000
# 4           127    Male   50                         15         PG   45000
# 5           128    Male   55                         18         PG   45000
# 6           129    Male   48                         12         UG   50000
# 7           130  Female   37                          9         PG   28000
# 8           131    Male   28                          3         UG   14000
# 9           132    Male   34                          5         UG   30000
# 10          133  Female   36                          6         PG   35000
# ...

# %%
plt.hist(df['Age'], bins=20, color= 'DArkblue')
# Out:
# (array([2., 0., 1., 0., 1., 2., 1., 2., 0., 0., 1., 2., 3., 1., 1., 0., 0.,
#         1., 1., 1.]),
#  array([23.  , 24.85, 26.7 , 28.55, 30.4 , 32.25, 34.1 , 35.95, 37.8 ,
#         39.65, 41.5 , 43.35, 45.2 , 47.05, 48.9 , 50.75, 52.6 , 54.45,
#         56.3 , 58.15, 60.  ]),
#  <BarContainer object of 20 artists>)

# %%
sn.barplot(x='Gender',y='Age', hue='No of years of experience', data= df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sn.boxplot(x='Age', y='No of years of experience', data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='No of years of experience'>

# %%
print(df['No of years of experience'].quantile(0.05))
print(df['No of years of experience'].quantile(0.95))
# Out:
# 2.0
# 20.0

# %%
df['No of years of experience']= np.where(df['No of years of experience']>2,2,df['No of years of experience'])
df['No of years of experience']= np.where(df['No of years of experience']<20,20,df['No of years of experience'])

# %%
sn.boxplot(df['No of years of experience'])
# Out:
# C:\Users\DIBYOJIT\AppData\Local\RStudio\ctx\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No of years of experience'>

# %%
import numpy as np

# %%
my_array= [1,2,3,4,5,6]
np.array(my_array).shape
# Out:
# (6,)

# %%
import matplotlib.pyplot as plt
k= range(0,20)
i= []
for z in k:
    z= z*2
    z=z+1
    i.append(z)
    plt.plot(i, color="blue", label="Plot", linewidth=4)
    plt.xlabel("z")
    plt.ylabel("k")
    plt/title("Line Plot")
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use(['dark_background', 'fivethirtyeight'])
import warnings
warnings.filterwarnings(action='ignore')

# %%
df= pd.read_csv("C:/Users/DIBYOJIT/OneDrive/Documents/Population_Data.csv")
df
# Out:
#        Region  Office Location Id   Indians Foreigners Indian_Male  \
# 0   Region 31                   1  6,43,596  28,83,782    4,40,445
# 1   Region 17                   9  3,19,933  15,01,899    2,13,477
# 2   Region 12                   4  1,94,379   6,50,744    1,61,803
# 3   Region 22                  15  1,07,360   4,70,708      85,343
# 4   Region 23                  13    55,351   3,29,980      31,796
# 5   Region 20                   6    55,044   2,02,485      48,310
# 6    Region 1                  11    44,727   2,67,200      36,430
# 7   Region 24                  10    43,437   2,32,626      29,633
# 8   Region 11                   3    35,923   2,17,717      27,005
# 9    Region 4                   8    29,149   1,54,197      19,460
# 10  Region 37                  14    20,023     82,361      16,247
# 11  Region 34                  12    19,613   1,26,178      14,368
# 12  Region 18                  22    18,297   1,16,492      12,690
# ...

# %%
df.head()
# Out:
#       Region  Office Location Id   Indians Foreigners Indian_Male  \
# 0  Region 31                   1  6,43,596  28,83,782    4,40,445
# 1  Region 17                   9  3,19,933  15,01,899    2,13,477
# 2  Region 12                   4  1,94,379   6,50,744    1,61,803
# 3  Region 22                  15  1,07,360   4,70,708      85,343
# 4  Region 23                  13    55,351   3,29,980      31,796
#
#   Indian_Female Foreigners_Male Foreigners_Female Total Population
# 0      2,03,151       27,63,718            72,515        35,27,378
# 1      1,06,456       14,49,303            27,671          1821832
# 2        32,576        6,31,660            10,652           845123
# 3        22,017        4,50,267             6,389           578068
# 4        23,555        3,25,105             3,684           385331

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              38 non-null     object
#  1   Office Location Id  38 non-null     int64
#  2   Indians             38 non-null     object
#  3   Foreigners          38 non-null     object
#  4   Indian_Male         38 non-null     object
#  5   Indian_Female       38 non-null     object
#  6   Foreigners_Male     38 non-null     object
#  7   Foreigners_Female   38 non-null     object
#  8   Total Population    38 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 2.8+ KB

# %%
numeric= ["Indians", "Foreigners", "Indian_Male", "Indian_Female", "Foreigners_Male", "Foreigners_Female", "Total Population"]

# %%
def cleaner(z):
    return z.replace(',' , ' ')

# %%
for i in df[numeric]:
    df[i]= df[i].apply(cleaner)
df.head()
# Out:
#       Region  Office Location Id   Indians Foreigners Indian_Male  \
# 0  Region 31                   1  6 43 596  28 83 782    4 40 445
# 1  Region 17                   9  3 19 933  15 01 899    2 13 477
# 2  Region 12                   4  1 94 379   6 50 744    1 61 803
# 3  Region 22                  15  1 07 360   4 70 708      85 343
# 4  Region 23                  13    55 351   3 29 980      31 796
#
#   Indian_Female Foreigners_Male Foreigners_Female Total Population
# 0      2 03 151       27 63 718            72 515        35 27 378
# 1      1 06 456       14 49 303            27 671          1821832
# 2        32 576        6 31 660            10 652           845123
# 3        22 017        4 50 267             6 389           578068
# 4        23 555        3 25 105             3 684           385331

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Region              38 non-null     object
#  1   Office Location Id  38 non-null     int64
#  2   Indians             38 non-null     object
#  3   Foreigners          38 non-null     object
#  4   Indian_Male         38 non-null     object
#  5   Indian_Female       38 non-null     object
#  6   Foreigners_Male     38 non-null     object
#  7   Foreigners_Female   38 non-null     object
#  8   Total Population    38 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 2.8+ KB

# %%
df[numeric]= df[numeric].apply(pd.to_numeric)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\RStudio\ctx\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "6 43 596"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35296\3912233321.py in <module>
# ----> 1 df[numeric]= df[numeric].apply(pd.to_numeric)
#       2 df.info()
#
# ~\AppData\Local\RStudio\ctx\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~\AppData\Local\RStudio\ctx\lib\site-packages\pandas\core\apply.py in apply(self)
# ...

# %%
list= [2,3,222,14,25]
list[:-1]
# Out:
# [2, 3, 222, 14]
